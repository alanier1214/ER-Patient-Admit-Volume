# %%
####################################################################
######### INFS 772 - Spring 2026 Data Science Competition ##########
####################################################################

## Import libraries
import pandas as pd 

## Read in data file
data = pd.read_csv('DSU-Dataset.csv')
